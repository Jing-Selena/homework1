# %% [markdown]
# # Exercise:
#
# In this exercise, you will work with a data set in "mtcars.csv" that contains information on 31 cars. We will create a collection of scatterplots showing the relationship between horsepower (hp) and miles per gallon (mpg), displacement(disp) and quarter mile time (qsec).  Also, in each of these plots we will distinguish between automatic (am = 0) and manual (am=1) cars. Please follow the following steps:
#
# **Step 0:** create a gitHub repository for this exercise. In your local repository, copy this jupyter file. Make sure you commit and push changes to your online repository after each step.
#
# **Step 1:** Read the file into a data frame
#
# **Step 2:** Dispaly statistics about differnt columns
#
# **Step 3:** Create two dataframes from the origial one to represent manual and automatic cars
#
# **Step 4:** Now Let's first create a 1x3 figure on which we will place the three plots. Give the figure a title of "Understanding the Effect of Horspower on other Features"
#
# **Step 5:** On the first axis plot hp versus miles per gallon for manual cars only
#
# **Step 6:** Add to the same axis a plot for automatic car, using a different color
#
# **Step 7:** Repeat 5 and 6 for hp vs qsec
#
# **Step 8:** Repeat 5 and 6 for hp vs disp
#
# **Step 9:** Use descriptive labels, good markers, colors, and legends to enhance your graph
#
# **Step 10:** Save figures to your computer
#
#
# Advanced: Add two horizontal lines to the first plot denoting the respective average mpg for automatic and manual cars respectively.

# %%
##Step 1: Read the file into a data frame

import pandas as pd
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt

data=pd.read_csv("mtcars(1).csv")
data.head()
# Out:
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
##Step 2: Dispaly statistics about differnt columns

data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
##Step 3: Create two dataframes from the origial one to represent manual and automatic cars
data_manual=data[data["am"]==1]
data_automatic=data[data["am"]==0]
data_manual.head()
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 17       Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18    Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
#
#     carb
# 0      4
# 1      4
# 2      1
# 17     1
# 18     2

# %%
##Step 4: Now Let's first create a 1x3 figure on which we will place the three plots. 
##Give the figure a title of "Understanding the Effect of Horspower on other Features"
##Step 5: On the first axis plot hp versus miles per gallon for manual cars only
##Step 6: Add to the same axis a plot for automatic car, using a different color
##Step 7: Repeat 5 and 6 for hp vs qsec
##Step 8: Repeat 5 and 6 for hp vs disp
##Step 9: Use descriptive labels, good markers, colors, and legends to enhance your graph
##Step 10: Save figures to your computer
##horsepower (hp) and miles per gallon (mpg), displacement(disp) and quarter mile time (qsec)
fig,ax=plt.subplots(1,3,figsize=(30,10))
plt.suptitle('Understanding the Effect of Horspower on other Features',fontsize=50)
ax[0].plot(data_manual.hp,data_manual.mpg,"o",label="manual")
ax[0].plot(data_automatic.hp,data_automatic.mpg,"o",label="automatic")
ax[0].set_xlabel('horsepower (hp)',fontsize=20)
ax[0].set_ylabel('miles per gallon (mpg)',fontsize=20)
ax[0].legend()

ax[1].plot(data_manual.hp,data_manual.disp,"o",label="manual")
ax[1].plot(data_automatic.hp,data_automatic.disp,"o",label="automatic")
ax[1].set_xlabel('horsepower (hp)',fontsize=20)
ax[1].set_ylabel('displacement(disp)',fontsize=20)
ax[1].legend()

ax[2].plot(data_manual.hp,data_manual.qsec,"o",label="manual")
ax[2].plot(data_automatic.hp,data_automatic.qsec,"o",label="automatic")
ax[2].set_xlabel('horsepower (hp)',fontsize=20)
ax[2].set_ylabel('quarter mile time (qsec)',fontsize=20)
ax[2].legend()

plt.savefig(r'D:\figure.png',dpi=100,bbox_inches='tight')
